# %% [markdown]
# # 1.	Business Problem

# %% [raw]
# problem statment : Prepare a classification model using the Naive Bayes algorithm for the salary dataset. Train and test datasets are given separately. Use both for model building.

# %% [markdown]
# # 2.Data collection

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("SalaryData_Train.csv")

# %%
df.sample(4)
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 24384   30   Self-emp-inc        HS-grad            9   Married-civ-spouse
# 4229    32    Federal-gov      Assoc-voc           11        Never-married
# 26142   64   Self-emp-inc        HS-grad            9   Married-civ-spouse
# 15242   58        Private   Some-college           10   Married-civ-spouse
#
#                occupation     relationship                 race    sex  \
# 24384   Handlers-cleaners          Husband                White   Male
# 4229       Prof-specialty   Other-relative   Asian-Pac-Islander   Male
# 26142     Exec-managerial          Husband                White   Male
# 15242      Prof-specialty          Husband                White   Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 24384            0            0            60   United-States   <=50K
# 4229             0            0            40   United-States   <=50K
# 26142            0            0            40   United-States    >50K
# 15242            0            0            42   United-States   <=50K

# %%
df.shape
# Out:
# (30161, 14)

# %%
test_df=pd.read_csv('SalaryData_Test.csv')

# %%
test_df.sample(4)
# Out:
#        age          workclass      education  educationno  \
# 9013    50   Self-emp-not-inc        HS-grad            9
# 11456   72            Private        7th-8th            4
# 9382    35            Private   Some-college           10
# 13996   46            Private   Some-college           10
#
#              maritalstatus        occupation    relationship    race      sex  \
# 9013    Married-civ-spouse   Exec-managerial         Husband   White     Male
# 11456   Married-civ-spouse     Other-service         Husband   White     Male
# 9382              Divorced      Adm-clerical   Not-in-family   White   Female
# 13996   Married-civ-spouse      Craft-repair         Husband   White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 9013             0            0            50   United-States   <=50K
# 11456            0            0            20   United-States   <=50K
# 9382             0            0            50   United-States   <=50K
# 13996            0            0            50   United-States    >50K

# %%
test_df.shape
# Out:
# (15060, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
def set_of_data(col) : 
    return len(set(df[col]))

# %%
for i in df.columns: 
    print(f"{i} ----> {set_of_data(i)}")
# Out:
# age ----> 72
# workclass ----> 7
# education ----> 16
# educationno ----> 16
# maritalstatus ----> 7
# occupation ----> 14
# relationship ----> 6
# race ----> 5
# sex ----> 2
# capitalgain ----> 118
# capitalloss ----> 90
# hoursperweek ----> 94
# native ----> 40
# Salary ----> 2

# %%
# target colums is Salary

# %%
sns.scatterplot(df,x='age',y='capitalgain',hue='Salary')
# Out:
# <Axes: xlabel='age', ylabel='capitalgain'>

# %%
sns.scatterplot(df,x='age',y='capitalloss',hue='Salary')
# Out:
# <Axes: xlabel='age', ylabel='capitalloss'>
