# %% [markdown]
# # 1. Business Problem

# %% [raw]
# 1.A cloth manufacturing company is interested to know about the different attributes contributing to high
# sales. Build a decision tree & random forest model with Sales as target variable
# (first convert it into categorical variable).

# %% [raw]
# Understanding and classfication of the Sales

# %% [raw]
# What are different attributes to classfication of given Sales according regan
# 1) coustemer is Urban or not
# 2) classfing the Data base on US

# %% [raw]
# UnderStanding the feature in the give Data

# %% [raw]
#      Sales        float64   numrical
#  1   CompPrice    int64     numrical
#  2   Income       int64     numrical
#  3   Advertising  int64     numrical
#  4   Population   int64     numrical
#  5   Price        int64     numrical
#  6   ShelveLoc    object    Categorical
#  7   Age          int64     numrical
#  8   Education    int64     numrical
#  9   Urban        object    Categorical
#  10  US           object    Categorical

# %% [markdown]
# # 2.Data Gathering

# %%
import pandas as pd 
df=pd.read_csv("Company_Data.csv")
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  Education Urban   US
# 0   9.50        138      73           11         276    120       Bad   42         17   Yes  Yes
# 1  11.22        111      48           16         260     83      Good   65         10   Yes  Yes
# 2  10.06        113      35           10         269     80    Medium   59         12   Yes  Yes
# 3   7.40        117     100            4         466     97    Medium   55         14   Yes  Yes
# 4   4.15        141      64            3         340    128       Bad   38         13   Yes   No

# %%
df.sample(4)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  Education Urban   US
# 220  10.59        131     120           15         262    124    Medium   30         10   Yes  Yes
# 385   5.87        131      73           13         455    132    Medium   62         17   Yes  Yes
# 181   7.43        121      83            0          79     91    Medium   68         11   Yes   No
# 192   7.56        108      26            0         408     93    Medium   56         14    No   No

# %% [markdown]
# # 3.EDA(Exploratory Data Analysis )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df.shape
# Out:
# (400, 11)

# %%
df.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %% [markdown]
# <h3>3.1 Working with numrical </h3>

# %%
# histogroam 
def col_histogream(col)  :  
    sns.histplot(df[col])

# %%
num=['Sales','CompPrice','Income','Advertising','Population','Price','Age','Education']
for i in num: 
    col_histogream(i)
    plt.show()

# %%
def col_displot(col ) : 
    sns.displot(df,x=col,hist=False)

# %%
for i in num: 
    col_distplot(i)
    plt.show()
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# C:\Users\raj\AppData\Local\Temp\ipykernel_28360\3004451061.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
# Power transformer on given graphs 
#1) Income , Advertising  , Education

# %%
#outer ditation 
def box_plot(col): 
    sns.boxplot(df[col])

# %%
for i in num : 
    box_plot(i)
    plt.show()

# %%
# no outler in data

# %% [markdown]
# <h3>3.2catgorel</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
cat=['ShelveLoc','Urban','US']

# %%
# heat map 
k=pd.crosstab(df['ShelveLoc'],df['Urban'])
k
# Out:
# Urban      No  Yes
# ShelveLoc
# Bad        22   74
# Good       28   57
# Medium     68  151

# %%
sns.heatmap(k)
# Out:
# <Axes: xlabel='Urban', ylabel='ShelveLoc'>

# %%
k=pd.crosstab(df['ShelveLoc'],df['US'])
k
# Out:
# US         No  Yes
# ShelveLoc
# Bad        34   62
# Good       24   61
# Medium     84  135

# %%
sns.heatmap(k)
# Out:
# <Axes: xlabel='US', ylabel='ShelveLoc'>

# %%
k=pd.crosstab(df['Urban'],df['US'])
k
# Out:
# US     No  Yes
# Urban
# No     46   72
# Yes    96  186

# %%
sns.heatmap(k)
# Out:
# <Axes: xlabel='US', ylabel='Urban'>

# %% [markdown]
# # 4.Preprocessing

# %%
# Steps 1) Label incoder 
     #   2) Ordinal incoder 
        #2) power transfromer

# %%
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OrdinalEncoder 
lab= LabelEncoder()

# %%
set(df['ShelveLoc'])
# Out:
# {'Bad', 'Good', 'Medium'}

# %%
ord=OrdinalEncoder(categories=[['Bad','Medium','Good']])

# %%
df['ShelveLoc']=ord.fit_transform(df[['ShelveLoc']])

# %%
df.sample(4)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  Education Urban   US
# 185  10.07        130     100           11         449    107        1.0   64         10   Yes  Yes
# 10    9.01        121      78            9         150    100        0.0   26         10    No  Yes
# 216   5.73        141      33            0         243    144        1.0   34         17   Yes   No
# 187   6.03        117      32            0         142     96        0.0   62         17   Yes   No

# %%
df['ShelveLoc'].value_counts()
# Out:
# ShelveLoc
# 1.0    219
# 0.0     96
# 2.0     85
# Name: count, dtype: int64

# %%
df['Urban']=lab.fit_transform(df['Urban'])

# %%
df['US']=lab.fit_transform(df['US'])

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  Education  Urban  US
# 0     9.50        138      73           11         276    120        0.0   42         17      1   1
# 1    11.22        111      48           16         260     83        2.0   65         10      1   1
# 2    10.06        113      35           10         269     80        1.0   59         12      1   1
# 3     7.40        117     100            4         466     97        1.0   55         14      1   1
# 4     4.15        141      64            3         340    128        0.0   38         13      1   0
# ..     ...        ...     ...          ...         ...    ...        ...  ...        ...    ...  ..
# 395  12.57        138     108           17         203    128        2.0   33         14      1   1
# 396   6.14        139      23            3          37    120        1.0   55         11      0   1
# 397   7.41        162      26           12         368    159        1.0   40         18      1   1
# 398   5.94        100      79            7         284     95        0.0   50         12      1   1
# 399   9.71        134      37            0          27    120        2.0   49         16      1   1
#
# [400 rows x 11 columns]

# %% [markdown]
# # 4.Spliting of Data

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.iloc[:,:-1]
y=df[['US']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %% [markdown]
# # 5.Model Selection

# %%
from sklearn.tree import DecisionTreeClassifier ,plot_tree 
from sklearn.ensemble import RandomForestClassifier 
from xgboost import XGBClassifier

# %%
clf1=DecisionTreeClassifier()
clf2=RandomForestClassifier()
clf3=XGBClassifier()

# %%
clf1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf2.fit(X_train,y_train)
# Out:
# C:\Users\raj\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier()

# %%
clf3=clf3.fit(X_train,y_train)

# %%
#prediction 
y_pre1=clf1.predict(X_test)
y_pre2=clf2.predict(X_test)
y_pre3=clf3.predict(X_test)

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test,y_pre1)
# Out:
# 0.7875

# %%
accuracy_score(y_test,y_pre2)
# Out:
# 0.925

# %%
accuracy_score(y_test,y_pre3)
# Out:
# 0.9125

# %%
# for traing data 
y_train_p1=clf1.predict(X_train)
y_train_p2=clf2.predict(X_train)
y_train_p3=clf3.predict(X_train)

# %%
print(accuracy_score(y_train,y_train_p1))
print(accuracy_score(y_train,y_train_p2))
print(accuracy_score(y_train,y_train_p3))
# Out:
# 1.0
# 1.0
# 1.0

# %%
# over fiting on data

# %%
#Random forest is given good result

# %% [markdown]
# # 7.conclusion

# %% [markdown]
# after this peformaning the decision tree & random forest model i undestand that A cloth manufacturing company is interested to know
# sales. Build a  with Sales as target variable focues on urban points
