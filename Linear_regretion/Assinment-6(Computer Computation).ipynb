# %% [markdown]
# # Problem statment

# %% [raw]
# An online camputer price sales platform would like to improve its customer base and their experience by providing them an easy way to buy and sell cars. For this, they would like an automated model which can predict the price of the car once the user inputs the required factors

# %% [raw]
# Perform multilinear regression with price as the output variable and document the different RMSE values.

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Computer_Data.csv")

# %%
df.sample(4)
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen   cd multi premium  ads  \
# 6248        6249   2623     66  1200   24      15  yes   yes     yes   39
# 4317        4318   1695     66   340    8      14   no    no     yes  248
# 3310        3311   2669     50   340    8      14   no    no      no  307
# 5090        5091   1345     66   214    4      14   no    no     yes  182
#
#       trend
# 6248     35
# 4317     20
# 3310     16
# 5090     24

# %% [markdown]
# # Data Undestanding

# %%
df.shape
# Out:
# (6259, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6259 entries, 0 to 6258
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6259 non-null   int64
#  1   price       6259 non-null   int64
#  2   speed       6259 non-null   int64
#  3   hd          6259 non-null   int64
#  4   ram         6259 non-null   int64
#  5   screen      6259 non-null   int64
#  6   cd          6259 non-null   object
#  7   multi       6259 non-null   object
#  8   premium     6259 non-null   object
#  9   ads         6259 non-null   int64
#  10  trend       6259 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 538.0+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# speed         0
# hd            0
# ram           0
# screen        0
# cd            0
# multi         0
# premium       0
# ads           0
# trend         0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0        price        speed           hd          ram  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   3130.000000  2219.576610    52.011024   416.601694     8.286947
# std    1806.961999   580.803956    21.157735   258.548445     5.631099
# min       1.000000   949.000000    25.000000    80.000000     2.000000
# 25%    1565.500000  1794.000000    33.000000   214.000000     4.000000
# 50%    3130.000000  2144.000000    50.000000   340.000000     8.000000
# 75%    4694.500000  2595.000000    66.000000   528.000000     8.000000
# max    6259.000000  5399.000000   100.000000  2100.000000    32.000000
#
#             screen          ads        trend
# count  6259.000000  6259.000000  6259.000000
# mean     14.608723   221.301007    15.926985
# std       0.905115    74.835284     7.873984
# min      14.000000    39.000000     1.000000
# 25%      14.000000   162.500000    10.000000
# 50%      14.000000   246.000000    16.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Data Preprocesing

# %% [markdown]
# # EDA

# %%
num=['price','hd','ads','trend']
cat=['speed','ram','screen','cd','multi','premium']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi',
#        'premium', 'ads', 'trend'],
#       dtype='object')

# %%
# speed 
df['speed'].describe()
# Out:
# count    6259.000000
# mean       52.011024
# std        21.157735
# min        25.000000
# 25%        33.000000
# 50%        50.000000
# 75%        66.000000
# max       100.000000
# Name: speed, dtype: float64

# %%
# speed  
sns.kdeplot(df['speed']) # need to change it normal distbution  
# a district random varable can working
# Out:
# <Axes: xlabel='speed', ylabel='Density'>

# %%
sns.distplot(df['speed'])
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_20748\1884667340.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['speed'])
# <Axes: xlabel='speed', ylabel='Density'>

# %%
set(df['speed']) #
# Out:
# {25, 33, 50, 66, 75, 100}

# %%
df['speed'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# applying one hot encoder

# %%
#set(df['price']) 
# numrical colums to finding the output

# %%
sns.kdeplot(df['price']) # normal distubtion of data
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.displot(df['price'])

# %%
sns.boxplot(df['price']) # outlyer are in data
# Out:
# <Axes: ylabel='price'>

# %%
# hd 
# set(df['hd']) # it as numrcail
sns.kdeplot(df['hd'])
# Out:
# <Axes: xlabel='hd', ylabel='Density'>

# %%
sns.boxplot(df['hd'])
# Out:
# <Axes: ylabel='hd'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi',
#        'premium', 'ads', 'trend'],
#       dtype='object')

# %%
# ram 
set(df['ram']) 
#{2, 4, 8, 16, 24, 32} 
#categorcal colums
# Out:
# {2, 4, 8, 16, 24, 32}

# %%
df['ram'].value_counts()
# Out:
# ram
# 8     2320
# 4     2236
# 16     996
# 2      394
# 24     297
# 32      16
# Name: count, dtype: int64

# %%
df['ram'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
'''screen', 'cd', 'multi',
       'premium', 'ads', 'trend' '''
# Out:
# "screen', 'cd', 'multi',\n       'premium', 'ads', 'trend' "

# %%
set(df['screen']) # categoral colums
# Out:
# {14, 15, 17}

# %%
df['screen'].value_counts()
# Out:
# screen
# 14    3661
# 15    1992
# 17     606
# Name: count, dtype: int64

# %%
df['speed'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['multi'].value_counts()
# Out:
# multi
# no     5386
# yes     873
# Name: count, dtype: int64

# %%
df['multi'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['premium'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# set(df['ads'])
df['ads'].value_counts()
# Out:
# ads
# 339    339
# 307    307
# 298    298
# 292    292
# 283    283
# 275    275
# 273    273
# 267    267
# 259    259
# 249    249
# 248    248
# 246    246
# 225    225
# 216    216
# 205    205
# 191    191
# 182    182
# 176    176
# 163    163
# 162    162
# 158    158
# 152    152
# 139    139
# 132    132
# 129    129
# 108    108
# 100    100
# 95      95
# 94      94
# 39      78
# 75      75
# 52      52
# 51      51
# 40      40
# Name: count, dtype: int64

# %%
sns.kdeplot(df['ads'])
# Out:
# <Axes: xlabel='ads', ylabel='Density'>

# %%
sns.boxplot(df['ads'])
# Out:
# <Axes: ylabel='ads'>

# %%
# trandet 
#set(df['trend']) 1-35 
# 
sns.histplot(df['trend'])
# Out:
# <Axes: xlabel='trend', ylabel='Count'>

# %%
sns.kdeplot(df['trend'])
# Out:
# <Axes: xlabel='trend', ylabel='Density'>

# %%
num
# Out:
# ['price', 'hd', 'ads', 'trend']

# %%
cat
# Out:
# ['speed', 'ram', 'screen', 'cd', 'multi', 'premium']

# %%
sns.scatterplot(df,x='price',y='hd')
# Out:
# <Axes: xlabel='price', ylabel='hd'>

# %%
sns.scatterplot(df,x='price',y='ads')
# Out:
# <Axes: xlabel='price', ylabel='ads'>

# %%
sns.scatterplot(df,x='price',y='trend')
# Out:
# <Axes: xlabel='price', ylabel='trend'>

# %%
sns.scatterplot(df,x='price',y='hd',hue='speed')
# Out:
# <Axes: xlabel='price', ylabel='hd'>

# %%
sns.scatterplot(df,x='price',y='hd',hue='ram')
# Out:
# <Axes: xlabel='price', ylabel='hd'>

# %%
sns.scatterplot(df,x='hd',y='price',hue='screen')
# Out:
# <Axes: xlabel='hd', ylabel='price'>

# %%
sns.scatterplot(df,x='price',y='hd',hue='cd')
# Out:
# <Axes: xlabel='price', ylabel='hd'>

# %%
sns.scatterplot(df,x='hd',y='price',hue='premium')
# Out:
# <Axes: xlabel='hd', ylabel='price'>

# %%
for i in num : 
    sns.boxplot(df[i])
    plt.show()

# %%
for i in num: 
    sns.kdeplot(df[i])

# %%
from sklearn.preprocessing import MinMaxScaler 
scaler = MinMaxScaler()
for i in num: 
    k=scaler.fit_transform(df[[i]])
    sns.kdeplot(k)

# %%
ax=plt.figure(figsize=(12,4))
for i in range(len(num)): 
    plt.subplot(1,4,i+1)    
    k=scaler.fit_transform(df[[num[i]]])
    sns.boxplot(k)

# %%
# so by anylzed the data for given computer data and according to it the main cloums are the following 
# 1)price -->  target  
# 2)hd ---> feture-1

# %%
num
# Out:
# ['price', 'hd', 'ads', 'trend']

# %%
cat
# Out:
# ['speed', 'ram', 'screen', 'cd', 'multi', 'premium']

# %%
for i in num: 
    print(df['price'].corr(df[i]))
# Out:
# 0.9999999999999998
# 0.4302577939663473
# 0.05454047343531925
# -0.19998693529652786

# %%
# so only relteconship with

# %% [markdown]
# # Data Preprocessing

# %%
# data preproceing 
# zscore outier 
def range_of_limit(col): 
    list=[]
    mean=df[col].mean()
    std = df[col].std()
    upper_limte = mean + 3*std 
    lower_limte =mean - 3*std
    return upper_limte,lower_limte 


def capping(col ) : 
    upper_limte , lower_limte = range_of_limit(col)
    df[col] = np.where(df[col]>upper_limte 
                          , upper_limte , 
                         np.where(
                             df[col]<lower_limte , lower_limte,df[col]
                         ))

# %%
for i in num: 
    print(f"{i} upper and lower : {range_of_limit(i)}  max: {df[i].max()}  min: {df[i].min()}")
# Out:
# price upper and lower : (3961.9884766401724, 477.1647427239436)  max: 5399  min: 949
# hd upper and lower : (1192.2470290806918, -359.04364195814844)  max: 2100  min: 80
# ads upper and lower : (445.80685863001156, -3.204845528877172)  max: 339  min: 39
# trend upper and lower : (39.54893668525868, -7.694966402465898)  max: 35  min: 1

# %%
# price contans outliyers so useing caping for it 
import numpy as np 
upper_limte , lower_limte = range_of_limit('price')
df['price'] = np.where(df['price']>upper_limte 
                      , upper_limte , 
                     np.where(
                         df['price']<lower_limte , lower_limte,df['price']
                     ))

# %%
upper_limte
# Out:
# 3961.9884766401724

# %%
lower_limte
# Out:
# 477.1647427239436

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(y)
# Out:
# <Axes: ylabel='price'>

# %%
import numpy as np

# %%
sns.boxplot(df['hd'])
# Out:
# <Axes: ylabel='hd'>

# %%
# encoder 
from sklearn.preprocessing import LabelEncoder 
X
# Out:
#         hd  ads  speed  ram  screen   cd
# 0       80   94     25    4      14   no
# 1       85   94     33    2      14   no
# 2      170   94     25    4      15   no
# 3      170   94     25    8      14   no
# 4      340   94     33   16      14   no
# ...    ...  ...    ...  ...     ...  ...
# 6254   528   39    100    8      15   no
# 6255   850   39     66   16      15  yes
# 6256  1200   39    100   24      15  yes
# 6257   850   39    100   16      15  yes
# 6258   850   39    100   16      17  yes
#
# [6259 rows x 6 columns]

# %%
lable = LabelEncoder()
df['cd']=lable.fit_transform(df['cd'])

# %%
cat
# Out:
# ['speed', 'ram', 'screen', 'cd', 'multi', 'premium']

# %%
from sklearn.preprocessing import OneHotEncoder 
one = OneHotEncoder()
m=one.fit_transform(X[['speed']])

# %%
X=pd.get_dummies(X, columns=['screen','speed', 'ram'], dtype=int)

# %% [markdown]
# # Data spliting an model buliding

# %%
main_features = ['hd','ads','speed','ram','screen','cd']
target = ['price']

# %%
X=pd.DataFrame()
for i in main_features : 
    X[i]=df[i]

# %%
y=df['price']

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X.values,y.values,test_size=0.3,random_state=42)

# %% [markdown]
# # Model_building using normal method

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso 
from sklearn.svm import SVR 
from sklearn.ensemble import RandomForestRegressor 
from xgboost.sklearn import XGBRegressor

# %% [markdown]
# <h2>Simple Regression

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=reg.predict(X_test)

# %%
from sklearn.metrics import r2_score,roc_auc_score,root_mean_squared_error

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.5465338577200236

# %% [markdown]
# <h2>polynmal feaue

# %%
from sklearn.preprocessing import PolynomialFeatures 
pol = PolynomialFeatures(degree=2)
X_train_trf=pol.fit_transform(X_train)
X_test_trf=pol.transform(X_test)

# %%
reg1=LinearRegression()
reg1.fit(X_train_trf,y_train)
# Out:
# LinearRegression()

# %%
y_pred2=reg1.predict(X_test_trf)
r2_score(y_test,y_pred2)
# Out:
# 0.61435783726451

# %% [markdown]
# # Random forest Regression

# %%
reg3=RandomForestRegressor()
reg3.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred3=reg3.predict(X_test)
r2_score(y_test,y_pred3)  # with polynmaly featurs the accuracy is 79
# Out:
# 0.8148811448399659

# %% [markdown]
# # XGBoost Regressetion

# %%
# XGBoost Regressetion 
reg4 = XGBRegressor()
reg4.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred4=reg4.predict(X_test)
r2_score(y_test,y_pred4)
# Out:
# 0.8733038753827556

# %% [markdown]
# # deep learing ANN

# %%
import tensorflow

# %%
import tensorflow 
from tensorflow import keras 
from keras.layers import Dense,Flatten 
from keras import Sequential 
model =Sequential()

# %%
X_train.shape
# Out:
# (4381, 18)

# %%
model.add(Dense(10,activation="relu",input_dim=18))
model.add(Dense(10,activation="relu"))
model.add(Dense(1,activation='relu'))
# Out:
# C:\Users\raj\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │             190 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             110 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 311 (1.21 KB)
#  Trainable params: 311 (1.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])  # MSE for regression
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4570988.5000 - mae: 2060.9563 - val_loss: 2594721.5000 - val_mae: 1525.1454
# Epoch 2/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1845340.0000 - mae: 1224.8046 - val_loss: 674336.5625 - val_mae: 653.8956
# Epoch 3/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 575550.0625 - mae: 593.4774 - val_loss: 515032.6250 - val_mae: 545.5979
# Epoch 4/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 455805.3750 - mae: 515.4767 - val_loss: 414345.5000 - val_mae: 472.6011
# Epoch 5/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 393860.4375 - mae: 471.6693 - val_loss: 377035.1250 - val_mae: 442.1230
# Epoch 6/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 383232.3750 - mae: 454.6631 - val_loss: 366207.0938 - val_mae: 434.6031
# Epoch 7/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 361246.5312 - mae: 443.2173 - val_loss: 360024.4375 - val_mae: 434.4055
# Epoch 8/20
# ...

# %%
y_pred5 = model.predict(X_test)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# # Conclusion:

# %% [raw]
# Best model is XGboost model to give good results on data and  main feautes are
# [hd	,ads	,speed	,ram	,screen	,cd]
